# %%
import pandas as pd
import csv
import math

df = pd.read_csv("data_IA/contaminacion_madrid.csv", nrows = 5000, sep = ';')

dfinal = pd.DataFrame(df, columns = ['punto_muestreo', 'ano', 'mes',
                                     'dia', 'h01', 'h02', 'h05', 'h06',
                                     'h07', 'h08', 'h09', 'h10', 'h11',
                                     'h12', 'h13', 'h14', 'h15', 'h16',
                                     'h17', 'h18', 'h19', 'h20', 'h21',
                                     'h22', 'h23', 'h24'])

dfinal.mean().round(1)
# Out:
# punto_muestreo       inf
# ano               2022.0
# mes                 10.0
# dia                  4.5
# h01                 22.0
# h02                 20.5
# h05                 20.6
# h06                 25.3
# h07                 31.2
# h08                 31.8
# h09                 27.0
# h10                 23.8
# h11                 22.5
# h12                 22.2
# h13                 21.9
# h14                 22.5
# h15                 22.9
# h16                 23.8
# h17                 25.0
# h18                 28.7
# h19                 34.8
# h20                 35.9
# h21                 34.4
# h22                 31.1
# h23                 27.7
# h24                 24.3
# dtype: float64

# %%
##Si meto la media no me sale luego el punto de muestreo con el max
dfinal.loc['media'] = dfinal.mean()

dfinal.tail()

# %% [markdown]
# ## Mayores focos de contaminacion segun horas
# ## Mañana: 7.00 am (h07) Tarde: 8.00 pm (h20)

# %%
## Comprobando que no haya dos puntos de muestreo iguales
dfinal.duplicated(subset=['punto_muestreo'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1283     True
# 1284     True
# 1285     True
# 1286     True
# 1287     True
# Length: 1288, dtype: bool

# %%
## Buscamos el punto muestreo (x hora) que mas contaminacion capta
import pandas as pd

dfmax0 = pd.DataFrame(dfinal)

dfmax0[['punto_muestreo', 'h07']].max()
# Out:
# punto_muestreo    28180001_9_49
# h07                       478.0
# dtype: object

# %% [markdown]
# ### punto_muestreo    28180001_9_49
# ### h07                       248.0

# %%
dfmax1 = pd.DataFrame(dfinal)

dfmax1[['punto_muestreo', 'h20']].max()
# Out:
# punto_muestreo    28180001_9_49
# h20                       354.0
# dtype: object

# %% [markdown]
# ### punto_muestreo    28180001_9_49
# ### h20                       176.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(70, 20))
sns.lineplot(data=dfinal, x='punto_muestreo', y='h07', ax=ax)
# Out:
# <AxesSubplot:xlabel='punto_muestreo', ylabel='h07'>

# %%
fig, ax = plt.subplots(figsize=(70, 20))
sns.lineplot(data=dfinal, x='punto_muestreo', y='h20', ax=ax)
# Out:
# <AxesSubplot:xlabel='punto_muestreo', ylabel='h20'>

# %% [markdown]
# # Parte de MySQL

# %%
import mysql.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 import mysql.connector
#
# ModuleNotFoundError: No module named 'mysql'

# %%
con = mysql.connector.connect(user = "root", password = "frogs", host = "127.0.0.1")

# %%
#cursor = con.cursor()
#cursor.execute("CREATE DATABASE contaminacion_madrid;")

# %%
cursor = con.cursor()
cursor.execute("USE contaminacion_madrid;")

# %%
#cursor.execute("CREATE TABLE contaminacion_final (punto_muestreo VARCHAR(255), ano INT, mes INT, dia INT, h07 FLOAT(5,2), h20 FLOAT(5,2));")

# %%
for index, row in dfinal.iterrows():
    print()
    cursor.execute("INSERT INTO contaminacion_final([punto_muestreo], [ano], [mes], [dia], [h07], [h20],) values (?, ?, ?, ?, ?, ?)", row['punto_muestreo'], row['ano'], row['mes'], row['dia'], row['h07'], row['h20'])

con.commit()

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    con = mysql.connector.connect(user = "root", password = "frogs", host = "127.0.0.1")
    if con.is_connected():
        cursor=conn.cursor()
        cursor.execute("select database();")
        record= cursor.fetchone()
        print("You're connected to database:", record)
        cursor.execute('DROP TABLE IF EXISTS dfinal_data;')
        print('Creating table....')
        # in the below line please pass the create table statement which you want #to create
        cursor.execute("CREATE TABLE dfinal_data(punto_muestreo varchar(255), ano INT, mes INT, dia INT, h01 FROAT, h02 FROAT,h03 FROAT, h04 FROAT, h05 FROAT,h06 FROAT, h07 FROAT,h08 FROAT, h09 FROAT, h10 FROAT, h11 FROAT, h12 FROAT, h13 FROAT, h14 FROAT, h15 FROAT, h16 FROAT, h17 FROAT, h18 FROAT, h19 FROAT, h20 FROAT, h21 FROAT, h22 FROAT, h23 FROAT, h24 FROAT")
        print("Table is created...")
        # loop through the data frame
        for i, row in dfinal.iterrows():
            #here %s means string values
                sql = "INSERT INTO madriddn.dfinal_data VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
                cursor.execute(sql, tuple(row))
        #        print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
                con.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 import mysql.connector as mysql
#       2 from mysql.connector import Error
#       3 try:
#
# ModuleNotFoundError: No module named 'mysql'
