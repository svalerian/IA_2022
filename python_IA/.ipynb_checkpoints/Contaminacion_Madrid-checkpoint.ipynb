# %%
import pandas as pd
import csv
import math

df = pd.read_csv("../data_IA/contaminacion_madrid.csv", nrows = 5000, sep = ';')

dfinal = pd.DataFrame(df, columns = ['punto_muestreo', 'ano', 'mes',
                                     'dia', 'h01', 'h02', 'h05', 'h06',
                                     'h07', 'h08', 'h09', 'h10', 'h11',
                                     'h12', 'h13', 'h14', 'h15', 'h16',
                                     'h17', 'h18', 'h19', 'h20', 'h21',
                                     'h22', 'h23', 'h24'])

dfinal.mean().round(1)
# Out:
# punto_muestreo       inf
# ano               2022.0
# mes                  9.0
# dia                 13.5
# h01                 16.2
# h02                 15.5
# h05                 15.6
# h06                 17.5
# h07                 20.3
# h08                 19.7
# h09                 18.6
# h10                 18.6
# h11                 18.7
# h12                 19.0
# h13                 19.2
# h14                 19.3
# h15                 19.3
# h16                 19.2
# h17                 19.2
# h18                 19.3
# h19                 19.9
# h20                 20.6
# h21                 20.2
# h22                 19.0
# h23                 17.9
# h24                 16.8
# dtype: float64

# %%
##Si meto la media no me sale luego el punto de muestreo con el max
dfinal.loc['media'] = dfinal.mean()

dfinal.tail()

# %%
## Mayores focos de contaminacion segun horas 
## Mañana: 7.00 am (h07) Tarde: 8.00 pm (h20)

# %%
## Comprobando que no haya dos puntos de muestreo iguales
dfinal.duplicated(subset=['punto_muestreo'])

# %%
## Buscamos el punto muestreo (x hora) que mas contaminacion capta
import pandas as pd

dfmax0 = pd.DataFrame(dfinal)

dfmax0[['punto_muestreo', 'h07']].max()
# Out:
# punto_muestreo    28180001_9_49
# h07                       248.0
# dtype: object

# %%
### punto_muestreo    28180001_9_49
### h07                       248.0

# %%
dfmax1 = pd.DataFrame(dfinal)

dfmax1[['punto_muestreo', 'h20']].max()
# Out:
# punto_muestreo    28180001_9_49
# h20                       176.0
# dtype: object

# %%
### punto_muestreo    28180001_9_49
### h20                       176.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(70, 20))
sns.lineplot(data=dfinal, x='punto_muestreo', y='h07', ax=ax)
# Out:
# <AxesSubplot:xlabel='punto_muestreo', ylabel='h07'>

# %%
fig, ax = plt.subplots(figsize=(70, 20))
sns.lineplot(data=dfinal, x='punto_muestreo', y='h20', ax=ax)
# Out:
# <AxesSubplot:xlabel='punto_muestreo', ylabel='h20'>

# %%
# Parte de MySQL

# %%
import mysql.connector

# %%
con = mysql.connector.connect(user = "root", password = "Real Madrid1", host = "127.0.0.1")

# %%
cursor = con.cursor()
cursor.execute("CREATE DATABASE contaminacion_madrid;")

# %%
cursor = con.cursor()
cursor.execute("USE contaminacion_madrid;")

# %%
cursor.execute("CREATE TABLE contaminacion_final (punto_muestreo VARCHAR(255), ano INT, mes INT, dia INT, h07 FLOAT(5,2), h20 FLOAT(5,2));")

# %%
"""
for index, row in dfinal.iterrows():
    cursor.execute("INSERT INTO contaminacion_final([punto_muestreo], [ano], [mes], [dia], [h07], [h20],) values (?, ?, ?, ?, ?, ?)", row['punto_muestreo'], row['ano'], row['mes'], row['dia'], row['h07'], row['h20'])

con.commit()
"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
#       1 for index, row in dfinal.iterrows():
# ----> 2     cursor.execute("INSERT INTO contaminacion_final([punto_muestreo], [ano], [mes], [dia], [h07], [h20],) values (?, ?, ?, ?, ?, ?)", row['punto_muestreo'], row['ano'], row['mes'], row['dia'], row['h07'], row['h20'])
#       4 con.commit()
#
# TypeError: MySQLCursor.execute() takes from 2 to 4 positional arguments but 8 were given

# %%
# Out:
# /Users/SergioValerian/opt/anaconda3/envs/IA/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/IA/lib/python3.10/site-packages/pandas/io/sql.py:2023, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2022 try:
# -> 2023     cur.execute(*args, **kwargs)
#    2024     return cur
#
# File ~/opt/anaconda3/envs/IA/lib/python3.10/site-packages/mysql/connector/cursor.py:546, in MySQLCursor.execute(self, operation, params, multi)
#     545     if psub.remaining != 0:
# --> 546         raise ProgrammingError(
#     547             "Not all parameters were used in the SQL statement"
#     548         )
#     549 else:
#
# ProgrammingError: Not all parameters were used in the SQL statement
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 dfinal.to_sql('contaminacion_final', con, if_exists='append')
#
# File ~/opt/anaconda3/envs/IA/lib/python3.10/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~/opt/anaconda3/envs/IA/lib/python3.10/site-packages/pandas/io/sql.py:698, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693 elif not isinstance(frame, DataFrame):
#     694     raise NotImplementedError(
#     695         "'frame' argument should be either a Series or a DataFrame"
#     696     )
# --> 698 return pandas_sql.to_sql(
#     699     frame,
#     700     name,
#     701     if_exists=if_exists,
#     702     index=index,
#     703     index_label=index_label,
#     704     schema=schema,
#     705     chunksize=chunksize,
#     706     dtype=dtype,
#     707     method=method,
#     708     engine=engine,
#     709     **engine_kwargs,
#     710 )
#
# File ~/opt/anaconda3/envs/IA/lib/python3.10/site-packages/pandas/io/sql.py:2192, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2181             raise ValueError(f"{col} ({my_type}) not a string")
#    2183 table = SQLiteTable(
#    2184     name,
#    2185     self,
#    (...)
#    2190     dtype=dtype,
#    2191 )
# -> 2192 table.create()
#    2193 return table.insert(chunksize, method)
#
# File ~/opt/anaconda3/envs/IA/lib/python3.10/site-packages/pandas/io/sql.py:832, in SQLTable.create(self)
#     831 def create(self):
# --> 832     if self.exists():
#     833         if self.if_exists == "fail":
#     834             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/opt/anaconda3/envs/IA/lib/python3.10/site-packages/pandas/io/sql.py:816, in SQLTable.exists(self)
#     815 def exists(self):
# --> 816     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/opt/anaconda3/envs/IA/lib/python3.10/site-packages/pandas/io/sql.py:2200, in SQLiteDatabase.has_table(self, name, schema)
#    2197 wld = "?"
#    2198 query = f"SELECT name FROM sqlite_master WHERE type='table' AND name={wld};"
# -> 2200 return len(self.execute(query, [name]).fetchall()) > 0
#
# File ~/opt/anaconda3/envs/IA/lib/python3.10/site-packages/pandas/io/sql.py:2035, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2032     raise ex from inner_exc
#    2034 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2035 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SELECT name FROM sqlite_master WHERE type='table' AND name=?;': Not all parameters were used in the SQL statement
